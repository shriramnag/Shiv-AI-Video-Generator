# %% [markdown]
# # 🔱 **Shiv AI Master Pro**
# **Owner:** Shri Ram Nag | **Channel:** PAISAWALA20
#
# ---
# यह नोटबुक ऑटोमेटिकली गिटहब से कोड लोड करती है, हगिंग फेस से मॉडल डाउनलोड करती है और वीडियो जनरेट करती है।

# %%
# @title 🚀 १. सेटअप: गिटहब कोड और लाइब्रेरी
import os
import shutil

REPO_URL = "https://github.com/shriramnag/Shiv-AI-Video-Generator"
REPO_NAME = "Shiv-AI-Video-Generator"

if os.path.exists(REPO_NAME):
    shutil.rmtree(REPO_NAME)

print("गिटहब से कोड डाउनलोड हो रहा है...")
# !git clone {REPO_URL}
# %cd {REPO_NAME}

print("\nलाइब्रेरी इंस्टॉल हो रही हैं...")
# !pip install -U -q huggingface_hub diffusers transformers accelerate gradio opencv-python imageio-ffmpeg
print("\n✅ सेटअप पूरा हुआ, श्री राम नाग जी!")

# %%
# @title 🔑 २. मॉडल डाउनलोड (No Token Required)
from huggingface_hub import snapshot_download

MODEL_ID = "Shriramnag/Shiv-AI-Video-Generator"
print(f"\nहगिंग फेस से {MODEL_ID} डाउनलोड हो रहा है...")

snapshot_download(
    repo_id=MODEL_ID,
    local_dir="./shiv_model",
    use_auth_token=False,
    ignore_patterns=["*.msgpack", "*.bin", "*.h5"]
)
print("\n✅ मॉडल सफलतापूर्वक डाउनलोड हो गया!")

# %%
# @title 🔱 ३. वीडियो जनरेटर लॉन्च करें
# !python app.py
