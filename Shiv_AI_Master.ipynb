# %% [markdown]
# # 🔱 **Shiv AI Pro: Master Notebook**
# **Owner:** Shri Ram Nag | **Channel:** PAISAWALA20

# %%
# १. सेटअप: गिटहब से कोड लोड करें
import os
# !git clone https://github.com/shriramnag/Shiv-AI-Video-Generator
# %cd Shiv-AI-Video-Generator
# !pip install -U -q huggingface_hub diffusers transformers accelerate gradio opencv-python imageio-ffmpeg

# %%
# २. मॉडल डाउनलोड (No Token Required)
from huggingface_hub import snapshot_download
snapshot_download(repo_id="Shriramnag/Shiv-AI-Video-Generator", local_dir="./shiv_model", use_auth_token=False, ignore_patterns=["*.msgpack", "*.bin"])
print("✅ मॉडल रेडी!")

# %%
# ३. शिव एआई लॉन्च करें
# !python app.py
